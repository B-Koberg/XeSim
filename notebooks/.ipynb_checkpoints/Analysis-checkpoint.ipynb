# %%
import os
import glob
import hist
import dask
import uproot
import awkward as ak
import dask_awkward as da
import dask.dataframe as dd
import dask_histogram as dh
from dask.diagnostics import ProgressBar
import boost_histogram as bh
from particle import Particle, ParticleNotFound

import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

import pandas as pd

from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# # Meta-Daten und Tabellen für IDs

# %%
file = "/home/b/bkoberg/AGW_LowRad/data_sim/XeSim_Neutron/1b6c1fe/Analysis/test_0.root"
rfile = uproot.open(file)

print(f"The file contains {len(rfile.keys())} keys:")
for key in rfile.keys():
    print(f"  {key}")

print(f"\nExecuted with G4VERSION {rfile['G4VERSION_TAG'].member('fTitle')}")
print(f"Total runtime: {rfile['G4RUNTIME'].member('fVal')} seconds")
print(f"Number of events: {rfile['events/nbevents'].member('fVal')}")

print(f"\nUsing the macros:")
for macro in rfile["macros"].keys():
    print(f"--> {rfile['macros'][macro].member('fName')}")
    print(f"    File content hidden for brevity ...")
    for line in rfile["macros"][macro].member('fTitle').splitlines():
        print(f"    {line}")
    print("")
# Out:
# The file contains 15 keys:
#   G4VERSION_TAG;1
#   MC_TAG;1
#   MCVERSION_TAG;1
#   macros;1
#   macros/preinit.mac;1
#   macros/det_setup.mac;1
#   macros/src_neutron.mac;1
#   tables;1
#   tables/process_subtypes;1
#   tables/logical_volumes;1
#   tables/physical_volumes;1
#   events;1
#   events/nbevents;1
#   events/events;1
#   G4RUNTIME;1
#
# Executed with G4VERSION $Name: geant4-10-06-patch-02 $
# Total runtime: 1294.987471715 seconds
# Number of events: 100000
#
# Using the macros:
# --> preinit.mac
#     File content hidden for brevity ...
#     # ./macros/NeutronShielding/preinit.mac
#
#     /control/verbose 0
#     /run/verbose 0
#     /event/verbose 0
#     /tracking/verbose 0
#
#     # select how would you like to simulate radioactive decays
#     # setting 0 means that you would like to simulate the full decay chain in a single event
#     # setting 1 means that you want to manually postpone all radioactive decays
#     # If postpone is on each new isotope will be written in its own event together with subsequent gamma decays
#     /xe/Postponedecay 1
#
#     # set a lifetime threshold for secondaries produced via RadioactiveDecay process (daughter isotopes)
#     # if the daughter isotope lifetime > MaxLifeTime, postpone the track to the next event; keep in the running event otherwise
#     # only works if /xe/Postponedecay is set to 1
#     # default is 1 ns
#     /xe/MaxLifeTime 1 ns
#
#     # Do no record primary information or hit collections. Just eventid and special saves.
#     /analysis/settings/setRecordOnlyEventID true
#
#     # Store interactions resulting from neutron capture throughout the detector, not only sensitive volumes.
#     /analysis/settings/setRecordNeutronCapture true
#
#     /run/physics/setEMlowEnergyModel emlivermore
#     /run/physics/setHadronicModel QGSP_BERT_HP
#     /run/physics/setCerenkov false
#
#     /run/initialize
#
# --> det_setup.mac
#     File content hidden for brevity ...
#     # ./macros/NeutronShielding/det_setup.mac
#
#
# --> src_neutron.mac
#     File content hidden for brevity ...
#     # ./macros/NeutronShielding/src_neutron.mac
#
#     /Xe/gun/type Volume
#     /Xe/gun/shape Box
#
#     # full volume
#     #/Xe/gun/position 0 0 10000 mm
#     /Xe/gun/halfz 25000 mm
#     /Xe/gun/halfx 20000 mm
#     /Xe/gun/halfy 60000 mm
#
#     /Xe/gun/confine ConcretePhysicalVolume
#
#
#
#     /Xe/gun/particle neutron
#     #/Xe/gun/energy 5 MeV
#     /Xe/gun/energytype Spectrum
#     /Xe/gun/energyspectrum ./notebooks/ConstantDistribution.txt
#     /Xe/gun/point 0 0 3000 mm
#
#     # Remove generated secondaries from the event
#     /xe/KillGeneratedParticles opticalphoton e-

# %%
data_path = "/home/b/bkoberg/AGW_LowRad/data_sim/XeSim_Neutron/1b6c1fe/Analysis"
data_file_pattern = "test_*.root"

min_data_file_size = 5 * 1024 * 1024
data_files = glob.glob(f"{data_path}/{data_file_pattern}")
print(f"Found {len(data_files)} files matching pattern '{data_file_pattern}' in '{data_path}'.")

uproot_files = [{f:"events/events"} for f in data_files if os.path.getsize(f) > min_data_file_size]
print(f"Available keys in uproot files: {uproot.open(uproot_files[0]).keys()}")
# Out:
# Found 100 files matching pattern 'test_*.root' in '/home/b/bkoberg/AGW_LowRad/data_sim/XeSim_Neutron/1b6c1fe/Analysis'.
# Available keys in uproot files: ['eventid', 'type_pri', 'type_pri_id', 'e_pri', 'xp_pri', 'yp_pri', 'zp_pri', 'cx_pri', 'cy_pri', 'cz_pri', 'vol_pri', 'vol_pri_hash', 'NSave', 'Save_flag', 'Save_desc', 'Save_type', 'Save_x', 'Save_y', 'Save_z', 'Save_cx', 'Save_cy', 'Save_cz', 'Save_e', 'Save_t', 'Save_eventid', 'Save_trackid', 'NNAct', 'NAct_eventid', 'NAct_trackid', 'NAct_parentid', 'NAct_t', 'NAct_volume', 'NAct_volume_hash', 'NAct_x', 'NAct_y', 'NAct_z', 'NAct_process_name', 'NAct_process_category', 'NAct_process_ID', 'NAct_particle_name', 'NAct_particle_lifetime', 'NAct_particle_id', 'NAct_particle_atomicnumber', 'NAct_particle_mass', 'NAct_particle_excitationEnergy']

# %%
rfile = uproot.open(data_files[0])

physical_volumes = {}
for k,v in zip(*rfile["tables/physical_volumes"].arrays(library="np", how=list)):
    physical_volumes = {**physical_volumes, **{k: v for k, v in zip(k, v)}}

def get_volume_name(volume_id):
    """Get the volume name from the volume ID."""
    _hashes = {v:k for k,v in physical_volumes.items()}
    if volume_id in _hashes:
        return _hashes[volume_id]
    else:
        return f"Unknown volume ID {volume_id}"

subtypes_table = rfile["tables/process_subtypes"].arrays(library="np")

particle_ids = {}
for k,v in zip(subtypes_table['particle_id'], subtypes_table['particle_name']):
    particle_ids = {**particle_ids, **{k: v for k, v in zip(k, v)}}

def get_particle_name(particle_id):
    """Get the particle name from the particle PDG code."""
    if particle_id in particle_ids:
        return particle_ids[particle_id]
    else:
        try:
            try:
                particle = Particle.from_pdgid(particle_id)
                return particle.name
            except ParticleNotFound:
                # Check if nucleus
                if (str(particle_id)[0:2] == "10"):
                    # Remove isomeric state
                    _particle_id = int(str(particle_id)[:9] + "0")
                    particle = Particle.from_pdgid(_particle_id)
                    return particle.name+f"({str(particle_id)[9:]})"
                raise
        except Exception as e:
            return f"Unknown particle code {particle_id}"

process_subtype = {}
for k,v in zip(subtypes_table['process_subtype'], subtypes_table['process_name']):
    process_subtype = {**process_subtype, **{k: v for k, v in zip(k, v)}}

def get_process_name(process_id):
    """Get the process name from the process ID."""
    if process_id in process_subtype:
        return process_subtype[process_id]
    else:
        return f"Unknown process ID {process_id}"

# %% [markdown]
# # Loading using dask

# %% [markdown]
# ## Processes

# %%
da_processes = uproot.dask(uproot_files, filter_name=['eventid','NAct_volume', 'NAct_particle_id', 'NAct_process_ID'], allow_missing=True, step_size="2GB")

df = da.to_dataframe(da_processes)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/b/bkoberg/AGW_LowRad/home/bkoberg/XeSim/notebooks/Analysis.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell://jupyterhub.uni-muenster.de/home/b/bkoberg/AGW_LowRad/home/bkoberg/XeSim/notebooks/Analysis.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> da_processes = uproot.dask(uproot_files, filter_name=['eventid','NAct_volume', 'NAct_particle_id', 'NAct_process_ID'], allow_missing=True, step_size="2GB")
#       <a href='vscode-notebook-cell://jupyterhub.uni-muenster.de/home/b/bkoberg/AGW_LowRad/home/bkoberg/XeSim/notebooks/Analysis.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> df = da.to_dataframe(da_processes)
#
# File ~/.local/lib/python3.10/site-packages/uproot/_dask.py:283, in dask(files, filter_name, filter_typename, filter_branch, recursive, full_paths, step_size, steps_per_file, library, ak_add_doc, custom_classes, allow_missing, open_files, form_mapping, allow_read_errors_with_report, known_base_form, decompression_executor, interpretation_executor, **options)
#     281 elif library.name == "ak":
#     282     if open_files:
# --> 283         return _get_dak_array(
#     284             files,
#     285             filter_name,
#     286             filter_typename,
#     287             filter_branch,
#     288             recursive,
#     289             full_paths,
#     290             step_size,
#     291             custom_classes,
#     292             allow_missing,
#     293             real_options,
#     294             interp_options,
#     295             form_mapping,
#     296             steps_per_file,
#     297             allow_read_errors_with_report,
#     298             decompression_executor,
#     299             interpretation_executor,
#     300         )
#     301     else:
#     302         return _get_dak_array_delay_open(
#     303             files,
#     304             filter_name,
#    (...)
#     318             interpretation_executor,
#     319         )
#
# File ~/.local/lib/python3.10/site-packages/uproot/_dask.py:1626, in _get_dak_array(files, filter_name, filter_typename, filter_branch, recursive, full_paths, step_size, custom_classes, allow_missing, real_options, interp_options, form_mapping, steps_per_file, allow_read_errors_with_report, decompression_executor, interpretation_executor)
#    1612     expected_form, form_mapping_info = form_mapping(base_form)
#    1614 fn = _UprootRead(
#    1615     ttrees,
#    1616     common_keys,
#    (...)
#    1623     interpretation_executor=interpretation_executor,
#    1624 )
# -> 1626 return dask_awkward.from_map(
#    1627     fn,
#    1628     partition_args,
#    1629     divisions=tuple(divisions),
#    1630     label="from-uproot",
#    1631 )
#
# File ~/.local/lib/python3.10/site-packages/dask_awkward/lib/io/io.py:615, in from_map(func, args, label, token, divisions, meta, *iterables, **kwargs)
#     613 # Define collection name
#     614 label = label or funcname(func)
# --> 615 token = token or tokenize(func, iters, meta, **kwargs)
#     616 name = f"{label}-{token}"
#     618 # Define io_func
#     619
#     620 # FIXME: projection etc.
#
# File ~/.local/lib/python3.10/site-packages/dask/tokenize.py:76, in tokenize(ensure_deterministic, *args, **kwargs)
#      74     token = _ENSURE_DETERMINISTIC.set(ensure_deterministic)
#      75 try:
# ---> 76     return _tokenize(*args, **kwargs)
#      77 finally:
#      78     if token:
#
# File ~/.local/lib/python3.10/site-packages/dask/tokenize.py:34, in _tokenize(*args, **kwargs)
#      33 def _tokenize(*args: object, **kwargs: object) -> str:
# ---> 34     token: object = _normalize_seq_func(args)
#      35     if kwargs:
#      36         token = token, _normalize_seq_func(sorted(kwargs.items()))
#
# File ~/.local/lib/python3.10/site-packages/dask/tokenize.py:152, in _normalize_seq_func(seq)
#     150 _SEEN[id(seq)] = len(_SEEN), seq
#     151 try:
# --> 152     return tuple(map(_inner_normalize_token, seq))
#     153 finally:
#     154     del _SEEN[id(seq)]
#
# File ~/.local/lib/python3.10/site-packages/dask/tokenize.py:146, in _normalize_seq_func.<locals>._inner_normalize_token(item)
#     144 if isinstance(item, _IDENTITY_DISPATCH):
#     145     return item
# --> 146 return normalize_token(item)
#
# File ~/.local/lib/python3.10/site-packages/dask/utils.py:772, in Dispatch.__call__(self, arg, *args, **kwargs)
#     768 """
#     769 Call the corresponding method based on type of argument.
#     770 """
#     771 meth = self.dispatch(type(arg))
# --> 772 return meth(arg, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/dask/tokenize.py:208, in normalize_object(o)
#     205     return _normalize_dataclass(o)
#     207 try:
# --> 208     return _normalize_pickle(o)
#     209 except Exception:
#     210     _maybe_raise_nondeterministic(
#     211         f"Object {o!r} cannot be deterministically hashed. See "
#     212         "https://docs.dask.org/en/latest/custom-collections.html#implementing-deterministic-hashing "
#     213         "for more information."
#     214     )
#
# File ~/.local/lib/python3.10/site-packages/dask/tokenize.py:241, in _normalize_pickle(o)
#     239 buffers.clear()
#     240 try:
# --> 241     out = mod.dumps(o, protocol=5, buffer_callback=buffers.append)
#     242     mod.loads(out, buffers=buffers)
#     243     pik2 = hash_buffer_hex(out)
#
# File ~/.local/lib/python3.10/site-packages/uproot/model.py:1125, in VersionedModel.__getstate__(self)
#    1113 def __getstate__(self):
#    1114     return (
#    1115         {
#    1116             "base_names_versions": self.base_names_versions,
#    1117             "member_names": self.member_names,
#    1118             "class_flags": self.class_flags,
#    1119             "class_code": self.class_code,
#    1120             "class_streamer": self.class_streamer,
#    1121             "class_rawstreamers": self.class_rawstreamers,
#    1122             "writable": self.writable,
#    1123             "behaviors": self.behaviors,
#    1124         },
# -> 1125         {
#    1126             k: (
#    1127                 _LockPlaceholder()
#    1128                 if isinstance(v, _LockPlaceholder.lock_type)
#    1129                 else v
#    1130             )
#    1131             for k, v in self.__dict__.items()
#    1132         },
#    1133     )
#
# File ~/.local/lib/python3.10/site-packages/uproot/model.py:1125, in <dictcomp>(.0)
#    1113 def __getstate__(self):
#    1114     return (
#    1115         {
#    1116             "base_names_versions": self.base_names_versions,
#    1117             "member_names": self.member_names,
#    1118             "class_flags": self.class_flags,
#    1119             "class_code": self.class_code,
#    1120             "class_streamer": self.class_streamer,
#    1121             "class_rawstreamers": self.class_rawstreamers,
#    1122             "writable": self.writable,
#    1123             "behaviors": self.behaviors,
#    1124         },
# -> 1125         {
#    1126             k: (
#    1127                 _LockPlaceholder()
#    1128                 if isinstance(v, _LockPlaceholder.lock_type)
#    1129                 else v
#    1130             )
#    1131             for k, v in self.__dict__.items()
#    1132         },
#    1133     )
#
# KeyboardInterrupt:

# %%
only_LXe_volume = df[df['NAct_volume'] == "LXe"]

only_LXe_volume = only_LXe_volume[['NAct_particle_id','NAct_process_ID']]

# %%
with ProgressBar():
    grouped_data = only_LXe_volume.groupby(['NAct_particle_id','NAct_process_ID']).size().compute()


grouped_data.index = grouped_data.index.set_levels(
    grouped_data.index.levels[0].map(lambda x: get_particle_name(x)), level = 0
)
grouped_data.index = grouped_data.index.set_levels(
    grouped_data.index.levels[1].map(lambda x: get_process_name(x)), level = 1
)
# Out:
# [                                        ] | 0% Completed | 425.60 us
# [########################################] | 100% Completed | 192.01 s

# %%
grouped_data[grouped_data.index.get_level_values(0).str.contains('Unknown particle code', na=True)]
# Out:
# Series([], dtype: int64)

# %%
_data = grouped_data[grouped_data.values > 300]


_particles = np.unique(_data.index.get_level_values(0))
_processes = np.unique(_data.index.get_level_values(1))

def get_value(data,pr,p):
    try:
        return data[p,pr]
    except:
        return 0

_counts = {pr: [get_value(_data,pr,p) for p in _particles] for pr in _processes} 

plt.figure(dpi=150)

x = np.arange(len(_particles))
bottom = np.zeros(len(_particles))
for pr in _processes:
    plt.bar(x, _counts[pr], 0.8, label=pr, bottom=bottom)
    bottom += np.array(_counts[pr])

ax = plt.gca()
ax.set_xticks(x)
ax.set_xticklabels(_particles, rotation=90, ha='center')

plt.xlabel("Particle name")
plt.ylabel("Counts")
plt.title("Neutron activation products")
plt.yscale("log")

plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Positions

# %%
da_positions_pri = uproot.dask(uproot_files, filter_name=['eventid','xp_pri', 'yp_pri', 'zp_pri','type_pri_id', 'vol_pri' ], allow_missing=True, step_size="2GB")
da_positions_NAct = uproot.dask(uproot_files, filter_name=['eventid','NAct_volume', 'NAct_x', 'NAct_y', 'NAct_z' ], allow_missing=True, step_size="2GB")

df_pri = da.to_dataframe(da_positions_pri)
df_NAct = da.to_dataframe(da_positions_NAct)

# %%
neutron = 2112

data_pri = df_pri[df_pri['type_pri_id'] == neutron]
# Out:
# -9110.0

# %%
x_range = (data_pri['xp_pri'].min().compute(), data_pri['xp_pri'].max().compute())
y_range = (data_pri['yp_pri'].min().compute(), data_pri['yp_pri'].max().compute())
z_range = (data_pri['zp_pri'].min().compute(), data_pri['zp_pri'].max().compute())

# %%
h = dh.histogramdd([data_pri["xp_pri"], data_pri["yp_pri"], data_pri["zp_pri"]], 
                   bins=(100, 100, 100), 
                   range=(x_range, y_range, z_range), histogram=True)

# %%
h.compute()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/b/bkoberg/AGW_LowRad/home/bkoberg/XeSim/notebooks/Analysis.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell://jupyterhub.uni-muenster.de/home/b/bkoberg/AGW_LowRad/home/bkoberg/XeSim/notebooks/Analysis.ipynb#X62sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> h.compute()
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:372, in DaskMethodsMixin.compute(self, **kwargs)
#     348 def compute(self, **kwargs):
#     349     """Compute this dask collection
#     350
#     351     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     370     dask.compute
#     371     """
# --> 372     (result,) = compute(self, traverse=False, **kwargs)
#     373     return result
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:653, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     645     return args
#     647 schedule = get_scheduler(
#     648     scheduler=scheduler,
#     649     collections=collections,
#     650     get=get,
#     651 )
# --> 653 dsk = collections_to_dsk(collections, optimize_graph, **kwargs)
#     654 keys, postcomputes = [], []
#     655 for x in collections:
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:422, in collections_to_dsk(collections, optimize_graph, optimizations, **kwargs)
#     420 for opt, val in groups.items():
#     421     dsk, keys = _extract_graph_and_keys(val)
# --> 422     dsk = opt(dsk, keys, **kwargs)
#     424     for opt_inner in optimizations:
#     425         dsk = opt_inner(dsk, keys, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/dask_awkward/lib/optimize.py:58, in all_optimizations(dsk, keys, **_)
#      56 # Perform dask-awkward specific optimizations.
#      57 with typetracer_nochecks():
# ---> 58     dsk = optimize(dsk, keys=keys)
#      59 # Perform Blockwise optimizations for HLG input
#      60 dsk = optimize_blockwise(dsk, keys=keys)
#
# File ~/.local/lib/python3.10/site-packages/dask_awkward/lib/optimize.py:79, in optimize(dsk, keys, **_)
#      77 which = dask.config.get("awkward.optimization.which")
#      78 if "columns" in which:
# ---> 79     dsk = optimize_columns(dsk, keys)
#      80 if "layer-chains" in which:
#      81     dsk = rewrite_layer_chains(dsk, keys)
#
# File ~/.local/lib/python3.10/site-packages/dask_awkward/lib/optimize.py:209, in optimize_columns(dsk, keys)
#     180 """Run column projection optimization.
#     181
#     182 This optimization determines which columns from an
#    (...)
#     206
#     207 """
#     208 # 1. Build-and-evaluate typetracer-annotated graph
# --> 209 projection_data = _prepare_buffer_projection(dsk, keys)
#     210 if projection_data is None:
#     211     return dsk
#
# File ~/.local/lib/python3.10/site-packages/dask_awkward/lib/optimize.py:150, in _prepare_buffer_projection(dsk, keys)
#     147 for layer in hlg.layers.values():
#     148     layer.__dict__.pop("_cached_dict", None)
# --> 150 results = get_sync(hlg, list(minimal_keys))
#     152 # Touch all the buffers associated with the given output keys
#     153 for out in results:
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:562, in get_sync(dsk, keys, **kwargs)
#     557 """A naive synchronous version of get_async
#     558
#     559 Can be useful for debugging.
#     560 """
#     561 kwargs.pop("num_workers", None)  # if num_workers present, remove it
# --> 562 return get_async(
#     563     synchronous_executor.submit,
#     564     synchronous_executor._max_workers,
#     565     dsk,
#     566     keys,
#     567     **kwargs,
#     568 )
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:505, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     503 while state["waiting"] or state["ready"] or state["running"]:
#     504     fire_tasks(chunksize)
# --> 505     for key, res_info, failed in queue_get(queue).result():
#     506         if failed:
#     507             exc, tb = loads(res_info)
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:547, in SynchronousExecutor.submit(self, fn, *args, **kwargs)
#     545 fut = Future()
#     546 try:
# --> 547     fut.set_result(fn(*args, **kwargs))
#     548 except BaseException as e:  # noqa: B036
#     549     fut.set_exception(e)
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:243, in batch_execute_tasks(it)
#     239 def batch_execute_tasks(it):
#     240     """
#     241     Batch computing of multiple tasks with `execute_task`
#     242     """
# --> 243     return [execute_task(*a) for a in it]
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:243, in <listcomp>(.0)
#     239 def batch_execute_tasks(it):
#     240     """
#     241     Batch computing of multiple tasks with `execute_task`
#     242     """
# --> 243     return [execute_task(*a) for a in it]
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:234, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     232     failed = False
#     233 except BaseException as e:  # noqa: B036
# --> 234     result = pack_exception(e, dumps)
#     235     failed = True
#     236 return key, result, failed
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:229, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     227 try:
#     228     task, data = loads(task_info)
# --> 229     result = task(data)
#     230     id = get_id()
#     231     result = dumps((result, id))
#
# File ~/.local/lib/python3.10/site-packages/dask/_task_spec.py:745, in Task.__call__(self, values)
#     736     kwargs = {
#     737         k: (
#     738             kw({k: values[k] for k in kw.dependencies})
#    (...)
#     742         for k, kw in self.kwargs.items()
#     743     }
#     744     return self.func(*new_argspec, **kwargs)
# --> 745 return self.func(*new_argspec)
#
# File ~/.local/lib/python3.10/site-packages/awkward/_dispatch.py:38, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      35 @wraps(func)
#      36 def dispatch(*args, **kwargs):
#      37     # NOTE: this decorator assumes that the operation is exposed under `ak.`
# ---> 38     with OperationErrorContext(name, args, kwargs):
#      39         gen_or_result = func(*args, **kwargs)
#      40         if isgenerator(gen_or_result):
#
# File ~/.local/lib/python3.10/site-packages/awkward/_errors.py:80, in ErrorContext.__exit__(self, exception_type, exception_value, traceback)
#      78     self._slate.__dict__.clear()
#      79     # Handle caught exception
# ---> 80     raise self.decorate_exception(exception_type, exception_value)
#      81 else:
#      82     # Step out of the way so that another ErrorContext can become primary.
#      83     if self.primary() is self:
#
# File ~/.local/lib/python3.10/site-packages/awkward/_dispatch.py:64, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      62 # Failed to find a custom overload, so resume the original function
#      63 try:
# ---> 64     next(gen_or_result)
#      65 except StopIteration as err:
#      66     return err.value
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:141, in to_dataframe(array, how, levelname, anonymous)
#     138 yield (array,)
#     140 # Implementation
# --> 141 return _impl(array, how, levelname, anonymous)
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:160, in _impl(array, how, levelname, anonymous)
#     158 if how is not None:
#     159     out = None
# --> 160     for df in to_dataframe(
#     161         array, how=None, levelname=levelname, anonymous=anonymous
#     162     ):
#     163         if out is None:
#     164             out = df
#
# File ~/.local/lib/python3.10/site-packages/awkward/_dispatch.py:64, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      62 # Failed to find a custom overload, so resume the original function
#      63 try:
# ---> 64     next(gen_or_result)
#      65 except StopIteration as err:
#      66     return err.value
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:141, in to_dataframe(array, how, levelname, anonymous)
#     138 yield (array,)
#     140 # Implementation
# --> 141 return _impl(array, how, levelname, anonymous)
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:229, in _impl(array, how, levelname, anonymous)
#     227 tables = []
#     228 last_row_arrays = None
# --> 229 for column, row_arrays, col_names in recurse(layout2, [], ()):
#     230     if isinstance(layout, ak.record.Record):
#     231         row_arrays = row_arrays[1:]  # Record --> one-element RecordArray
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:209, in _impl.<locals>.recurse(layout, row_arrays, col_names)
#     199         return reduce(
#     200             iconcat,
#     201             (
#    (...)
#     205             [],
#     206         )
#     208 elif isinstance(layout, ak.contents.RecordArray):
# --> 209     return reduce(
#     210         iconcat,
#     211         (
#     212             recurse(layout._getitem_field(n), row_arrays, (*col_names, n))
#     213             for n in layout.fields
#     214         ),
#     215         [],
#     216     )
#     218 else:
#     219     return [(ak.operations.to_numpy(layout), row_arrays, col_names)]
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:212, in <genexpr>(.0)
#     199         return reduce(
#     200             iconcat,
#     201             (
#    (...)
#     205             [],
#     206         )
#     208 elif isinstance(layout, ak.contents.RecordArray):
#     209     return reduce(
#     210         iconcat,
#     211         (
# --> 212             recurse(layout._getitem_field(n), row_arrays, (*col_names, n))
#     213             for n in layout.fields
#     214         ),
#     215         [],
#     216     )
#     218 else:
#     219     return [(ak.operations.to_numpy(layout), row_arrays, col_names)]
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:219, in _impl.<locals>.recurse(layout, row_arrays, col_names)
#     209     return reduce(
#     210         iconcat,
#     211         (
#    (...)
#     215         [],
#     216     )
#     218 else:
# --> 219     return [(ak.operations.to_numpy(layout), row_arrays, col_names)]
#
# File ~/.local/lib/python3.10/site-packages/awkward/_dispatch.py:64, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      62 # Failed to find a custom overload, so resume the original function
#      63 try:
# ---> 64     next(gen_or_result)
#      65 except StopIteration as err:
#      66     return err.value
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_numpy.py:48, in to_numpy(array, allow_missing)
#      45 yield (array,)
#      47 # Implementation
# ---> 48 return _impl(array, allow_missing)
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_numpy.py:58, in _impl(array, allow_missing)
#      55 layout = ak.to_layout(array, allow_record=False)
#      57 backend = NumpyBackend.instance()
# ---> 58 numpy_layout = layout.to_backend(backend)
#      60 return numpy_layout.to_backend_array(allow_missing=allow_missing)
#
# File ~/.local/lib/python3.10/site-packages/awkward/contents/content.py:1304, in Content.to_backend(self, backend)
#    1302     return self
#    1303 else:
# -> 1304     return self._to_backend(backend)
#
# File ~/.local/lib/python3.10/site-packages/awkward/contents/numpyarray.py:1386, in NumpyArray._to_backend(self, backend)
#    1384 def _to_backend(self, backend: Backend) -> Self:
#    1385     return NumpyArray(
# -> 1386         self._raw(backend.nplike),
#    1387         parameters=self._parameters,
#    1388         backend=backend,
#    1389     )
#
# File ~/.local/lib/python3.10/site-packages/awkward/contents/numpyarray.py:194, in NumpyArray._raw(self, nplike)
#     193 def _raw(self, nplike=None):
# --> 194     return to_nplike(self.data, nplike, from_nplike=self._backend.nplike)
#
# File ~/.local/lib/python3.10/site-packages/awkward/_nplikes/__init__.py:50, in to_nplike(array, nplike, from_nplike)
#      45             raise TypeError(
#      46                 f"Can only convert a VirtualArray to numpy, cupy or typetracer nplikes. Received {type(nplike)}"
#      47             )
#      49 if nplike.known_data and not from_nplike.known_data:
# ---> 50     raise TypeError(
#      51         "Converting from an nplike without known data to an nplike with known data is not supported"
#      52     )
#      54 # Copy to host memory
#      55 if isinstance(from_nplike, awkward._nplikes.cupy.Cupy) and not isinstance(
#      56     nplike, awkward._nplikes.cupy.Cupy
#      57 ):
#
# TypeError: Converting from an nplike without known data to an nplike with known data is not supported
#
# This error occurred while calling
#
#     ak.to_dataframe(
#         <Array-typetracer [...] type='## * {eventid: int32, type_pri_id: va...'>
#     )

# %%
plt.figure(figsize=(10, 8))
plt.imshow(np.sum(h.compute(), axis=2), extent=(x_range[0], x_range[1], y_range[0], y_range[1]), origin='lower', aspect='auto')
plt.colorbar(label='Counts')
plt.xlabel('X Position (cm)')
plt.ylabel('Y Position (cm)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/b/bkoberg/AGW_LowRad/home/bkoberg/XeSim/notebooks/Analysis.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell://jupyterhub.uni-muenster.de/home/b/bkoberg/AGW_LowRad/home/bkoberg/XeSim/notebooks/Analysis.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(10, 8))
# ----> <a href='vscode-notebook-cell://jupyterhub.uni-muenster.de/home/b/bkoberg/AGW_LowRad/home/bkoberg/XeSim/notebooks/Analysis.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> plt.imshow(np.sum(h.compute(), axis=2), extent=(x_range[0], x_range[1], y_range[0], y_range[1]), origin='lower', aspect='auto')
#       <a href='vscode-notebook-cell://jupyterhub.uni-muenster.de/home/b/bkoberg/AGW_LowRad/home/bkoberg/XeSim/notebooks/Analysis.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.colorbar(label='Counts')
#       <a href='vscode-notebook-cell://jupyterhub.uni-muenster.de/home/b/bkoberg/AGW_LowRad/home/bkoberg/XeSim/notebooks/Analysis.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> plt.xlabel('X Position (cm)')
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:372, in DaskMethodsMixin.compute(self, **kwargs)
#     348 def compute(self, **kwargs):
#     349     """Compute this dask collection
#     350
#     351     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     370     dask.compute
#     371     """
# --> 372     (result,) = compute(self, traverse=False, **kwargs)
#     373     return result
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:653, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     645     return args
#     647 schedule = get_scheduler(
#     648     scheduler=scheduler,
#     649     collections=collections,
#     650     get=get,
#     651 )
# --> 653 dsk = collections_to_dsk(collections, optimize_graph, **kwargs)
#     654 keys, postcomputes = [], []
#     655 for x in collections:
#
# File ~/.local/lib/python3.10/site-packages/dask/base.py:422, in collections_to_dsk(collections, optimize_graph, optimizations, **kwargs)
#     420 for opt, val in groups.items():
#     421     dsk, keys = _extract_graph_and_keys(val)
# --> 422     dsk = opt(dsk, keys, **kwargs)
#     424     for opt_inner in optimizations:
#     425         dsk = opt_inner(dsk, keys, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/dask_awkward/lib/optimize.py:58, in all_optimizations(dsk, keys, **_)
#      56 # Perform dask-awkward specific optimizations.
#      57 with typetracer_nochecks():
# ---> 58     dsk = optimize(dsk, keys=keys)
#      59 # Perform Blockwise optimizations for HLG input
#      60 dsk = optimize_blockwise(dsk, keys=keys)
#
# File ~/.local/lib/python3.10/site-packages/dask_awkward/lib/optimize.py:79, in optimize(dsk, keys, **_)
#      77 which = dask.config.get("awkward.optimization.which")
#      78 if "columns" in which:
# ---> 79     dsk = optimize_columns(dsk, keys)
#      80 if "layer-chains" in which:
#      81     dsk = rewrite_layer_chains(dsk, keys)
#
# File ~/.local/lib/python3.10/site-packages/dask_awkward/lib/optimize.py:209, in optimize_columns(dsk, keys)
#     180 """Run column projection optimization.
#     181
#     182 This optimization determines which columns from an
#    (...)
#     206
#     207 """
#     208 # 1. Build-and-evaluate typetracer-annotated graph
# --> 209 projection_data = _prepare_buffer_projection(dsk, keys)
#     210 if projection_data is None:
#     211     return dsk
#
# File ~/.local/lib/python3.10/site-packages/dask_awkward/lib/optimize.py:150, in _prepare_buffer_projection(dsk, keys)
#     147 for layer in hlg.layers.values():
#     148     layer.__dict__.pop("_cached_dict", None)
# --> 150 results = get_sync(hlg, list(minimal_keys))
#     152 # Touch all the buffers associated with the given output keys
#     153 for out in results:
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:562, in get_sync(dsk, keys, **kwargs)
#     557 """A naive synchronous version of get_async
#     558
#     559 Can be useful for debugging.
#     560 """
#     561 kwargs.pop("num_workers", None)  # if num_workers present, remove it
# --> 562 return get_async(
#     563     synchronous_executor.submit,
#     564     synchronous_executor._max_workers,
#     565     dsk,
#     566     keys,
#     567     **kwargs,
#     568 )
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:505, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     503 while state["waiting"] or state["ready"] or state["running"]:
#     504     fire_tasks(chunksize)
# --> 505     for key, res_info, failed in queue_get(queue).result():
#     506         if failed:
#     507             exc, tb = loads(res_info)
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:547, in SynchronousExecutor.submit(self, fn, *args, **kwargs)
#     545 fut = Future()
#     546 try:
# --> 547     fut.set_result(fn(*args, **kwargs))
#     548 except BaseException as e:  # noqa: B036
#     549     fut.set_exception(e)
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:243, in batch_execute_tasks(it)
#     239 def batch_execute_tasks(it):
#     240     """
#     241     Batch computing of multiple tasks with `execute_task`
#     242     """
# --> 243     return [execute_task(*a) for a in it]
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:243, in <listcomp>(.0)
#     239 def batch_execute_tasks(it):
#     240     """
#     241     Batch computing of multiple tasks with `execute_task`
#     242     """
# --> 243     return [execute_task(*a) for a in it]
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:234, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     232     failed = False
#     233 except BaseException as e:  # noqa: B036
# --> 234     result = pack_exception(e, dumps)
#     235     failed = True
#     236 return key, result, failed
#
# File ~/.local/lib/python3.10/site-packages/dask/local.py:229, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     227 try:
#     228     task, data = loads(task_info)
# --> 229     result = task(data)
#     230     id = get_id()
#     231     result = dumps((result, id))
#
# File ~/.local/lib/python3.10/site-packages/dask/_task_spec.py:745, in Task.__call__(self, values)
#     736     kwargs = {
#     737         k: (
#     738             kw({k: values[k] for k in kw.dependencies})
#    (...)
#     742         for k, kw in self.kwargs.items()
#     743     }
#     744     return self.func(*new_argspec, **kwargs)
# --> 745 return self.func(*new_argspec)
#
# File ~/.local/lib/python3.10/site-packages/awkward/_dispatch.py:38, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      35 @wraps(func)
#      36 def dispatch(*args, **kwargs):
#      37     # NOTE: this decorator assumes that the operation is exposed under `ak.`
# ---> 38     with OperationErrorContext(name, args, kwargs):
#      39         gen_or_result = func(*args, **kwargs)
#      40         if isgenerator(gen_or_result):
#
# File ~/.local/lib/python3.10/site-packages/awkward/_errors.py:80, in ErrorContext.__exit__(self, exception_type, exception_value, traceback)
#      78     self._slate.__dict__.clear()
#      79     # Handle caught exception
# ---> 80     raise self.decorate_exception(exception_type, exception_value)
#      81 else:
#      82     # Step out of the way so that another ErrorContext can become primary.
#      83     if self.primary() is self:
#
# File ~/.local/lib/python3.10/site-packages/awkward/_dispatch.py:64, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      62 # Failed to find a custom overload, so resume the original function
#      63 try:
# ---> 64     next(gen_or_result)
#      65 except StopIteration as err:
#      66     return err.value
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:141, in to_dataframe(array, how, levelname, anonymous)
#     138 yield (array,)
#     140 # Implementation
# --> 141 return _impl(array, how, levelname, anonymous)
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:160, in _impl(array, how, levelname, anonymous)
#     158 if how is not None:
#     159     out = None
# --> 160     for df in to_dataframe(
#     161         array, how=None, levelname=levelname, anonymous=anonymous
#     162     ):
#     163         if out is None:
#     164             out = df
#
# File ~/.local/lib/python3.10/site-packages/awkward/_dispatch.py:64, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      62 # Failed to find a custom overload, so resume the original function
#      63 try:
# ---> 64     next(gen_or_result)
#      65 except StopIteration as err:
#      66     return err.value
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:141, in to_dataframe(array, how, levelname, anonymous)
#     138 yield (array,)
#     140 # Implementation
# --> 141 return _impl(array, how, levelname, anonymous)
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:229, in _impl(array, how, levelname, anonymous)
#     227 tables = []
#     228 last_row_arrays = None
# --> 229 for column, row_arrays, col_names in recurse(layout2, [], ()):
#     230     if isinstance(layout, ak.record.Record):
#     231         row_arrays = row_arrays[1:]  # Record --> one-element RecordArray
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:209, in _impl.<locals>.recurse(layout, row_arrays, col_names)
#     199         return reduce(
#     200             iconcat,
#     201             (
#    (...)
#     205             [],
#     206         )
#     208 elif isinstance(layout, ak.contents.RecordArray):
# --> 209     return reduce(
#     210         iconcat,
#     211         (
#     212             recurse(layout._getitem_field(n), row_arrays, (*col_names, n))
#     213             for n in layout.fields
#     214         ),
#     215         [],
#     216     )
#     218 else:
#     219     return [(ak.operations.to_numpy(layout), row_arrays, col_names)]
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:212, in <genexpr>(.0)
#     199         return reduce(
#     200             iconcat,
#     201             (
#    (...)
#     205             [],
#     206         )
#     208 elif isinstance(layout, ak.contents.RecordArray):
#     209     return reduce(
#     210         iconcat,
#     211         (
# --> 212             recurse(layout._getitem_field(n), row_arrays, (*col_names, n))
#     213             for n in layout.fields
#     214         ),
#     215         [],
#     216     )
#     218 else:
#     219     return [(ak.operations.to_numpy(layout), row_arrays, col_names)]
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_dataframe.py:219, in _impl.<locals>.recurse(layout, row_arrays, col_names)
#     209     return reduce(
#     210         iconcat,
#     211         (
#    (...)
#     215         [],
#     216     )
#     218 else:
# --> 219     return [(ak.operations.to_numpy(layout), row_arrays, col_names)]
#
# File ~/.local/lib/python3.10/site-packages/awkward/_dispatch.py:64, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      62 # Failed to find a custom overload, so resume the original function
#      63 try:
# ---> 64     next(gen_or_result)
#      65 except StopIteration as err:
#      66     return err.value
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_numpy.py:48, in to_numpy(array, allow_missing)
#      45 yield (array,)
#      47 # Implementation
# ---> 48 return _impl(array, allow_missing)
#
# File ~/.local/lib/python3.10/site-packages/awkward/operations/ak_to_numpy.py:58, in _impl(array, allow_missing)
#      55 layout = ak.to_layout(array, allow_record=False)
#      57 backend = NumpyBackend.instance()
# ---> 58 numpy_layout = layout.to_backend(backend)
#      60 return numpy_layout.to_backend_array(allow_missing=allow_missing)
#
# File ~/.local/lib/python3.10/site-packages/awkward/contents/content.py:1304, in Content.to_backend(self, backend)
#    1302     return self
#    1303 else:
# -> 1304     return self._to_backend(backend)
#
# File ~/.local/lib/python3.10/site-packages/awkward/contents/numpyarray.py:1386, in NumpyArray._to_backend(self, backend)
#    1384 def _to_backend(self, backend: Backend) -> Self:
#    1385     return NumpyArray(
# -> 1386         self._raw(backend.nplike),
#    1387         parameters=self._parameters,
#    1388         backend=backend,
#    1389     )
#
# File ~/.local/lib/python3.10/site-packages/awkward/contents/numpyarray.py:194, in NumpyArray._raw(self, nplike)
#     193 def _raw(self, nplike=None):
# --> 194     return to_nplike(self.data, nplike, from_nplike=self._backend.nplike)
#
# File ~/.local/lib/python3.10/site-packages/awkward/_nplikes/__init__.py:50, in to_nplike(array, nplike, from_nplike)
#      45             raise TypeError(
#      46                 f"Can only convert a VirtualArray to numpy, cupy or typetracer nplikes. Received {type(nplike)}"
#      47             )
#      49 if nplike.known_data and not from_nplike.known_data:
# ---> 50     raise TypeError(
#      51         "Converting from an nplike without known data to an nplike with known data is not supported"
#      52     )
#      54 # Copy to host memory
#      55 if isinstance(from_nplike, awkward._nplikes.cupy.Cupy) and not isinstance(
#      56     nplike, awkward._nplikes.cupy.Cupy
#      57 ):
#
# TypeError: Converting from an nplike without known data to an nplike with known data is not supported
#
# This error occurred while calling
#
#     ak.to_dataframe(
#         <Array-typetracer [...] type='## * {eventid: int32, type_pri_id: va...'>
#     )

# %% [markdown]
# ## With Hist

# %%
hGen = hist.Hist(hist.axis.Regular(*x_range, 200, name="xp_pri", underflow=False, overflow=False),
                 hist.axis.Regular(*y_range, 200, name="yp_pri", underflow=False, overflow=False),
                 hist.axis.Regular(*z_range, -300, name="zp_pri", underflow=False, overflow=False),
                 storage=hist.storage.Int64())

for array, report in tqdm(uproot.iterate(uproot_files, filter_name=columns, cut=None, allow_missing=True,
                                         step_size="2GB", report=True)):
    try:
        hGen.fill(ak.ravel(array["xp_pri"]),
                  ak.ravel(array["yp_pri"]),
                  ak.ravel(array["zp_pri"]))

    except Exception as e:
        print(f"Error {e}!")
        print(report)
# Out:
# 20it [00:46,  2.32s/it]

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))
hGen[:,:, sum].plot2d(ax=axs[0])
hGen[:, sum, :].plot2d(ax=axs[1])
plt.show()
